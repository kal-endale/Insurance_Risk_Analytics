# %%
import pandas as pd

# Load the insurance data into a pandas DataFrame
df = pd.read_csv(r'D:\KAIM-9\Week-3\Insurance_Risk_Analytics\data\Data\insurance_data.csv')


# Display the first 5 rows to inspect the data
display(df.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2
#       3 # Load the insurance data into a pandas DataFrame
#       4 df = pd.read_csv(r'D:\KAIM-9\Week-3\Insurance_Risk_Analytics\data\Data\insurance_data.csv')
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd

# Load the insurance data into a pandas DataFrame
df = pd.read_csv(r'D:\KAIM-9\Week-3\Insurance_Risk_Analytics\data\Data\insurance_data.csv')


# Display the first 5 rows to inspect the data
display(df.head())

# %%
print('hello')
